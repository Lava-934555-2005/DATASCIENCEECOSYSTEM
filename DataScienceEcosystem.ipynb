# %% [markdown]
# TITTLE:DATASCIENCE TOOLS AND ECOSYSTEM

# %% [markdown]
# INTRODUCTION: In this notebook, datascience tools and ecosystem are summarized

# %% [markdown]
# DATASCIENCE LANGUAGES:Numbers list:python,r,sql,julia

# %% [markdown]
# DATASCIENCE LIBRARIES:Numbered list:Numpy,pandas,matplotlib,scikit-learn
# | Data Science Tools |
# |------------------|
# | Jupyter Notebook  |
# | RStudio           |
# | VSCode            |

# %% [markdown]
# ARITHMETIC EXPRESSSION INTRODUCTION:### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# OBJECTIVES
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used libraries
# - Understand basic arithmetic operations in Python
# - Explore data science tools

# %% [markdown]
# AUTHOR: LAVANYA THATCHANAMOORTHTY

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335
